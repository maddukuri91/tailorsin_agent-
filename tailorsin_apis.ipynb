# %% [markdown]
# # tailorsin.com - api's

# %% [markdown]
# ### fetch customer basic info

# %%
# --------------------------------
# Client Type Classification
# --------------------------------

import requests
url = "https://crm.tailorsin.com/tailorsin-api/api/getclient.php"


params = {
    "mobile": "9701667788"
}

response = requests.get(url, params=params)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"status":"success","type":"new_user","type_label":"New User","description":"mobile number not found - client does not exist yet","client":null}

# %%
# --------------------------------
# fetch customer info
# --------------------------------

import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/customerinfo.php"

payload = {
    "mobile": "9701667788"
}

response = requests.get(url, params=payload)

print(response.status_code)
print(response.text)      # Print raw response first
# Out:
# 404
# {"status":"error","message":"customer not found"}

# %%
# --------------------------------
# get custom fabric estimation
# --------------------------------

import requests


url = "https://crm.tailorsin.com/tailorsin-api/api/customfabricestimation.php"

payload = {
    "client_name": "veer",
    "primary_no": "917287874454",
    "secondary_no": "917287874454"
}

response = requests.post(
    url,
    json=payload
)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"status":"success","message":"thanks! your custom fabric estimation request has been received, our team will get in touch with you shortly","data":{"request_id":17,"client":{"id":43299,"cname":"veer","primary_no":"917287874454"},"secondary_no":"917287874454","status":"Pending","created_at":"2026-09-13 06:46:27"}}

# %%
# --------------------------------
# get bulk order enquiry
# --------------------------------

import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/bulkorderenquiry.php"

payload = {
    "client_name": "veer",
    "primary_no": "917287874454",
    "secondary_no": "917287874454"
}

response = requests.post(
    url,
    json=payload
)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"status":"success","message":"thank you! our agent will get in touch with you soon regarding your bulk order enquiry","data":{"alert_id":1759,"client":{"id":43299,"cname":"veer","primary_no":"919701667788","secondary_no":"917287874454"},"client_action":"fetched","created_at":"2026-09-13 12:21:23"}}

# %% [markdown]
# ## User - registartion/delete/schedule visit

# %%
# --------------------------------
# Register a new client
# --------------------------------

import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/clientregistration.php"


payload = {

    "client_name": "veer",
    "primary_no": "917287874454",
    "secondary_no": "917287874454"
    
}



response = requests.post(url, json=payload)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'status': 'success', 'action': 'fetched', 'message': 'client already registered, returning existing record', 'data': {'id': '43299', 'cname': 'veer', 'whatsapp': '919701667788', 'tel': '917287874454', 'add_date': '2026-09-13 06:15:45'}}

# %%
# --------------------------------
# Remove client using phone no
# --------------------------------

import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/deleteclient.php"

payload = {
    "mobile": "919701667788"
}

response = requests.post(url, json=payload)

print("Status Code:", response.status_code)
print("Response:", response.text)
# Out:
# Status Code: 200
# Response: {"status":"success","message":"client removed successfully","data":{"id":"43310","cname":"Veer","mobile":"919701667788","deleted":true}}

# %%
# --------------------------------
# Book a visit
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/bookappointment.php"

payload ={
    
    "mobile": "919701667788",
    "store_id": 1,
    "bookdate": "2026-09-14",
    "booktime": "11:00 AM - 12:00 PM"
}

response = requests.post(url, json=payload)

print("Status Code:", response.status_code)
print("Response:", response.text)
# Out:
# Status Code: 200
# Response: {"status":"success","message":"appointment booked successfully","data":{"appointment_id":1405,"client":{"id":"43299","cname":"veer","whatsapp":"919701667788"},"store":{"id":1,"store_name":"Hyderabad"},"bookdate":"2026-09-14","bookdate_display":"14-09-2026","booktime":"11:00 AM - 12:00 PM","bookstatus":"Confirmed"}}

# %% [markdown]
# ## user address management

# %%
# --------------------------------
# fetch customer address
# --------------------------------

import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/customeraddress.php"

params = {
    "mobile": "9701667788"
}

response = requests.get(url, params=params)

print("Status Code:", response.status_code)

if response.status_code == 200:
    try:
        addresses = response.json()
        print(addresses)
    except ValueError:
        print("Response is not JSON")
        print(response.text)
else:
    print(response.text)
# Out:
# Status Code: 200
# {'status': 'success', 'client': {'id': 43299, 'cname': 'veer', 'mobile': '919701667788'}, 'count': 1, 'addresses': [{'id': '4997', 'cid': '43299', 'adr_id': '99', 'address': 'Flat 302, Green Meadows', 'address2': 'Near Metro Station', 'locality': 'Kondapur', 'city': 'Hyderabad', 'zone': '', 'pincode': '500084', 'lat': '', 'lng': '', 'tel': ''}]}

# %%
# --------------------------------
# add customer address
# --------------------------------

import requests
url = "https://crm.tailorsin.com/tailorsin-api/api/addaddress.php"

payload = {
    
    "mobile": "919701667788",
    "address": "Flat 302, Green Meadows",
    "address2": "Near Metro Station",
    "locality": "Kondapur",
    "city": "Hyderabad",
    "pincode": "500084"
}

response = requests.post(url, json=payload)

print("Status Code:", response.status_code)
print(response.text)
# Out:
# Status Code: 200
# {"status":"success","message":"address added successfully","address_id":4997,"client":{"id":43299,"cname":"veer","mobile":"919701667788"},"data":{"id":4997,"cid":43299,"adr_id":99,"address":"Flat 302, Green Meadows","address2":"Near Metro Station","locality":"Kondapur","city":"Hyderabad","zone":"","pincode":"500084","lat":"","lng":"","tel":""}}

# %%
# --------------------------------
# delete customer address
# --------------------------------

import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/deleteaddress.php"

payload = {
    "mobile": "7287874454",
    "address_id": 4924
}

response = requests.post(url, json=payload)

print("Status Code:", response.status_code)
print(response.text)
# Out:
# Status Code: 200
# {"status":"success","message":"address deleted successfully, you can add a new one anytime","client":{"id":42748,"cname":"Bumble bee","mobile":"917287874454"},"address_id":4924,"deleted_address":"4-13, kotalopala street"}

# %% [markdown]
# ## User - order management

# %%
# --------------------------------
# place a new order
# --------------------------------

import requests
url = "https://crm.tailorsin.com/tailorsin-api/api/schedulepickup.php"

payload = {
    "mobile": "9701667788", 
    "pickup_date": "2026-09-14", 
    "pickup_time": 1,
    "address_id": 4997
}

response = requests.post(url, json=payload)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'status': 'success', 'message': 'pickup scheduled successfully', 'data': {'order_id': 14116, 'log_id': 38788, 'client': {'id': 43299, 'cname': 'veer', 'whatsapp': '919701667788', 'tel': '917287874454'}, 'pickup_date': '2026-09-14', 'pickup_time': 1, 'pickup_time_label': '9AM - 2PM', 'stage': 0, 'stage_label': 'order on pickup', 'logistics_status': 'Pending', 'pickup_address': {'id': '4997', 'address': 'Flat 302, Green Meadows', 'address2': 'Near Metro Station', 'locality': 'Kondapur', 'city': 'Hyderabad', 'pincode': '500084', 'lat': '', 'lng': ''}, 'created_at': '2026-09-13 07:04:39'}}

# %%
# --------------------------------
# place second order
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api//api/scheduleanotherpickup.php"
{
  "mobile": "919640864111",
  "pickup_date": "2026-07-15",
  "pickup_time": 1,
  "address_id": 4838
}

response = requests.post(url, json=payload)

print(response.status_code)
print(response.json())

# %%
# --------------------------------
# cancel order
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/cancelorder.php"
payload = {
    "mobile": "919701667788", 
    "order_id": 14116, 
    "reason": "Changed my mind" 
}

response = requests.post(url, json=payload)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'status': 'success', 'message': 'order cancelled successfully', 'data': {'order_id': 14116, 'client': {'id': '43299', 'cname': 'veer', 'mobile': '919701667788'}, 'stage': 8, 'stage_label': 'Cancelled', 'reason': 'Changed my mind', 'cancelled_at': '2026-09-13 12:36:57'}}

# %%
# --------------------------------
# modify order
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/modifyorder.php"


payload = {
    
    "mobile": "919640864111",
    "comment": "Please make the sleeves half instead of full",
    "order_id": 8842,
}

response = requests.get(url, params=payload)

print(response.status_code)
print(response.text)

# %%
# --------------------------------
# current order status
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/orderstatus.php"


payload = {
    "mobile": "9701667788"
}

response = requests.get(url, params=payload)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"status":"success","client":{"id":43299,"cname":"veer","mobile":"919701667788"},"count":1,"orders":[{"order_id":14116,"order_date":"2026-09-13 07:04:39","stage":0,"stage_label":"order on pickup","picked_up":false,"pickup_date":"2026-09-14","pickup_time":"1","last_update_date":"2026-09-13 07:04:39"}],"alteration_count":0,"alterations":[]}

# %%
# --------------------------------
# delivered orders
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/deliveredorders.php?"

payload = {
    "mobile": "9701667788"

}

response = requests.get(url, params=payload)

print(response.status_code)
print(response.text)
# Out:
# 200
# ...

# %%
import requests

# --------------------------------
# Get Alteration Eligible Orders
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/alterationeligibleorders.php"

params = {
    "mobile": "919701667788"
}

response = requests.get(url, params=params)

print("Status Code:", response.status_code)

try:
    print(response.json())
except ValueError:
    print(response.text)
# Out:
# Status Code: 200
# {'status': 'success', 'client': {'id': 42617, 'cname': 'Veerendra Maddukuri', 'mobile': '919701667788'}, 'message': 'no orders currently eligible for alteration for this client', 'count': 0, 'orders': []}

# %%
import requests

# --------------------------------
# Alteration Pickup
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/alterationpickup.php"

payload = {
    "mobile": "919701667788",
    "pickup_date": "2026-07-12",
    "pickup_time": 2,
    "address_id": 4916,
    "order_id": 13887,
    "notes": "Shorten sleeves by 1 inch"
}

response = requests.post(url, json=payload)

print("Status Code:", response.status_code)

try:
    print(response.json())
except ValueError:
    print(response.text)
# Out:
# Status Code: 200
# {'status': 'success', 'message': 'alteration pickup scheduled successfully for order #13887', 'data': {'log_id': 38111, 'order_id': 13887, 'order_stage': 7, 'order_stage_label': 'finished', 'order_closed': False, 'client': {'id': 42617, 'cname': 'Veerendra Maddukuri', 'whatsapp': '919701667788'}, 'pickup_date': '2026-07-12', 'pickup_time': 2, 'pickup_time_label': '2PM - 9PM', 'pickup_address': {'id': '4916', 'address': '201, kasturi nilayam, go green colony, Neknampur', 'address2': '', 'locality': '', 'city': 'Hyderabad', 'pincode': '500089', 'lat': '', 'lng': ''}, 'type': 'Alteration', 'notes': 'Shorten sleeves by 1 inch', 'status': 'Pending'}}

# %%
# --------------------------------
# drop off fabric
# --------------------------------
url = "https://crm.tailorsin.com/tailorsin-api/api/fabricdelivery.php"

payload = { 
    "mobile": "919701667788", 
    "store_id": 1, 
    "notes": "3 meters of cotton fabric for a shirt" 
}

response = requests.post(url, json=payload)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"status":"success","message":"you already have a pending fabric delivery request, our team will contact you soon","alert_id":"1760","client":{"id":43299,"cname":"veer","whatsapp":"919701667788"}}

# %% [markdown]
# ## Human handover

# %%
# --------------------------------
# human handover 
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/humanhandover.php"

payload = {
    "mobile": "919701667788"
}

response = requests.post(url, json=payload)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"status":"success","message":"handed over to human agent","data":{"id":"43299","cname":"veer","mobile":"919701667788","chat":1,"chatby":"Chatbot","last_spoken":1789283867}}
